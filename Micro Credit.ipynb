# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"C:\Users\sivap\OneDrive\Documents\Projects\micro credit\Micro Credit Project\Data file.csv",parse_dates=['pdate'])

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# - There as 209593 rows and 37 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# - we can observe float64, object,int62 dtypes in the data. object dtype will be encoded later.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# - There seems to be no null values

# %%
df.nunique()
# Out:
# Unnamed: 0              209593
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# ...

# %%
df['msisdn'].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 30080I90588    6
# 55809I89238    6
# 22038I88658    6
#               ..
# 36902I90840    1
# 17447I88689    1
# 59686I90584    1
# 00504I91190    1
# 65061I85339    1
# Name: msisdn, Length: 186243, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
mc =df[['label', 'aon', 'daily_decr30', 'daily_decr90',
       'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
       'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
       'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
       'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
       'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
       'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
       'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
       'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
       'payback90','pdate']]

# %%
mc['year'] = mc.pdate.dt.year
mc['month'] = mc.pdate.dt.month
mc['day'] = mc.pdate.dt.day
mc.drop('pdate',axis=1)
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
mc.nunique()
# Out:
# label                        2
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# maxamnt_loans90              3
# ...

# %%
mc['year'].unique()
# Out:
# array([2016], dtype=int64)

# %% [markdown]
# - since we only have data for a single year, we can drop the year column

# %%
mc.drop('year',axis=1)
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
mc['month'].unique()
# Out:
# array([7, 8, 6], dtype=int64)

# %% [markdown]
# - we see that data is from the months june july and august

# %%
mc.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [markdown]
# - aon has negative values, which again seems incorrect
# - daily_decr90 has negative values
# - rental30 has negative values
# - rental90 has negative values
# - last_rech_date_ma has negative values,
# - last_rech_date_da has negative values
# - medianmarechprebal30	has negative values
# - medianmarechprebal90 has negative values
#
# - cnt_da_rech30,fr_da_rech30,cnt_da_rech90,fr_da_rech90,last_rech_date_da,medianamnt_loans30,medianamnt_loans90 have about 75% data to be zero
# - If we observe the max values, we can see extremly high values that seems incorrect.

# %%
percentage = (df == 0.00).astype(int).sum(axis=0)*100/len(df)
zero = pd.DataFrame({'percentage':percentage})
zero
# Out:
#                       percentage
# Unnamed: 0              0.000000
# label                  12.482287
# msisdn                  0.000000
# aon                     0.000000
# daily_decr30            1.977165
# daily_decr90            1.938519
# rental30                3.609853
# rental90                3.300683
# last_rech_date_ma       9.896800
# last_rech_date_da      96.788061
# last_rech_amt_ma       10.017033
# cnt_ma_rech30          13.349205
# fr_ma_rech30           37.540853
# sumamnt_ma_rech30      13.349205
# medianamnt_ma_rech30   13.349205
# medianmarechprebal30   14.637893
# cnt_ma_rech90           9.995563
# fr_ma_rech90           31.371754
# sumamnt_ma_rech90       9.995563
# medianamnt_ma_rech90    9.995563
# medianmarechprebal90   11.160201
# cnt_da_rech30          98.037148
# fr_da_rech30           99.246635
# cnt_da_rech90          97.439323
# fr_da_rech90           99.587295
# cnt_loans30             1.554918
# amnt_loans30            1.554918
# ...

# %% [markdown]
# medianamnt_loans90,medianamnt_loans30,fr_da_rech90,cnt_da_rech90,fr_da_rech30,cnt_da_rech30,last_rech_date_da, have above 90% data as zero. Due to the lack of variation in the data it will not contribute much to the prdiction and shoul be dropped.

# %%
mc['aon']=mc['aon'].abs()
mc['daily_decr30']=mc['daily_decr30'].abs()
mc['daily_decr90']=mc['daily_decr90'].abs()
mc['rental30']=mc['rental30'].abs()
mc['rental90']=mc['rental90'].abs()
mc['last_rech_date_ma']= mc['last_rech_date_ma'].abs()
mc['last_rech_date_da']= mc['last_rech_date_da'].abs()
mc['medianmarechprebal30']= mc['medianmarechprebal30'].abs()
mc['medianmarechprebal90']= mc['medianmarechprebal90'].abs()

# %% [markdown]
# ### filtering columns

# %%
mc = mc[['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
       'last_rech_date_ma', 'last_rech_amt_ma',
       'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
       'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
       'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90',  'cnt_loans30', 'amnt_loans30',
       'maxamnt_loans30', 'cnt_loans90', 'amnt_loans90',
       'maxamnt_loans90','payback30', 'payback90',
       'month', 'day']]

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize =(35,35), facecolor='white')
plotnumber=1
for i in mc.columns:
    if mc[i].dtype != 'object':
        if plotnumber <= 37:
            ax = plt.subplot(7,6,plotnumber)
            sns.distplot(mc[i])
            plt.xlabel(i,fontsize=20)
    
    plotnumber +=1
plt.show()

# %% [markdown]
# - we can observe that all our numerical data are highly right skewed

# %%
mc.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30',
#        'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
#        'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
#        'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'payback30', 'payback90', 'month',
#        'day'],
#       dtype='object')

# %%
f =mc[['aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_amt_ma','sumamnt_ma_rech30','medianamnt_ma_rech30','medianmarechprebal30','sumamnt_ma_rech90','medianamnt_ma_rech90','medianmarechprebal90','cnt_ma_rech30','fr_ma_rech30','cnt_ma_rech90','fr_ma_rech90','cnt_loans30','amnt_loans30','maxamnt_loans30','cnt_loans90','amnt_loans90','payback30','payback90']]

# %%
plt.figure(figsize =(35,35), facecolor='white')
plotnumber=1
for i in f.columns:
    if plotnumber <= 30:
        ax = plt.subplot(5,6,plotnumber)
        sns.boxplot(f[i])
        plt.xlabel(i,fontsize=20)
    
    plotnumber +=1
plt.show()

# %% [markdown]
# - there are a lot of outliers in all the columns
# - rather than removing these outliers we can use imputation technique and replace them with mean/median values

# %%
def detect_outlier_iqr(f,variable):
    data = sorted(f)
    q1 = f[variable].quantile(.25)
    q3 = f[variable].quantile(.75)
    IQR =q3-q1
    lower = q1-(1.5*IQR)
    upper = q3+(1.5*IQR)
    
    return lower, upper

# %%
for i in f:
    lower_,upper_ = detect_outlier_iqr(f,i)
    print('Upper limit of',i,'is', upper_)
    print('Lower limit of',i,'is', lower_)
    print('**'*20)
# Out:
# Upper limit of aon is 2086.0
# Lower limit of aon is -858.0
# ****************************************
# Upper limit of daily_decr30 is 18046.3205
# Lower limit of daily_decr30 is -10759.8675
# ****************************************
# Upper limit of daily_decr90 is 19442.935000000027
# Lower limit of daily_decr90 is -11597.451666666682
# ****************************************
# Upper limit of rental30 is 7956.325000000001
# Lower limit of rental30 is -4294.275000000001
# ****************************************
# Upper limit of rental90 is 10016.275000000027
# Lower limit of rental90 is -5481.765000000016
# ****************************************
# Upper limit of last_rech_date_ma is 16.0
# Lower limit of last_rech_date_ma is -8.0
# ****************************************
# Upper limit of last_rech_amt_ma is 4617.5
# Lower limit of last_rech_amt_ma is -1538.5
# ****************************************
# Upper limit of sumamnt_ma_rech30 is 22715.0
# ...

# %%
plt.figure(figsize=(8,10))
vc= mc.label.value_counts()
explode =(0.1,0)

p = vc.plot(kind ='pie', explode= explode,autopct= '%1.1f%%',labels= vc.index, shadow = True)

# %% [markdown]
# - We see that 87.5% have paid the loan in time and 12.5% have failed to pay
# - The label data is imbalanced and will be required to be balance later on.

# %%
mc.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30',
#        'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
#        'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
#        'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'payback30', 'payback90', 'month',
#        'day'],
#       dtype='object')

# %%
sns.catplot(data= mc, x='label',y = 'daily_decr30')
plt.title('Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)')
plt.show()
sns.catplot(data= mc, x='label',y = 'daily_decr90')
plt.title('Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)')
plt.show()

# %% [markdown]
# - Daily amount spent averaged over last 30 daya for defaulters is a lot less as compared to non-defaulters.
# - Daily amount spent averaged over last 90 daya for defaulters is a lot less as compared to non-defaulters.

# %%
sns.barplot(data= mc, x='label',y = 'aon')
plt.title('Age on cellular network in days')
plt.show()

# %%
sns.catplot(data= mc, x='label',y = 'rental30')
plt.title('Average main account balance over last 30 days')
plt.show()
sns.catplot(data= mc, x='label',y = 'rental90')
plt.title('Average main account balance over last 90 days')
plt.show()

# %% [markdown]
# - Average main account balance 30 daya for defaulters is less as compared to non-defaulters.
# - Average main account balance  90 daya for defaulters is less as compared to non-defaulters.

# %%
sns.catplot(data= mc, x='label',y = 'last_rech_date_ma')
plt.title('Number of days till last recharge of main account')
plt.show()

sns.catplot(data= mc, x='label',y = 'last_rech_amt_ma')
plt.title('Amount of last recharge of main account (in Indonesian Rupiah)')
plt.show()

# %% [markdown]
# - No difference can be observed for 'last_rech_date_ma'
# - No difference can be observed for 'last_amt_date_ma'

# %%
sns.barplot(data= mc, x='label',y = 'cnt_ma_rech30')
plt.title('Number of times main account got recharged in last 30 days')
plt.show()

# %% [markdown]
# - The number of times defaulters have recharge is lesser as comapared to non defaulters
# - Re-payers were seen to recharge their account almost 4x the number of times defaulters were seen to recharge.

# %%
sns.catplot(data= mc, x='label',y = 'fr_ma_rech30')
plt.title('Frequency of main account recharged in last 30 days')
plt.show()

# %% [markdown]
# - Not much differeence an be observed here

# %%
sns.catplot(data= mc, x='label',y = 'sumamnt_ma_rech30')
plt.title('Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)')
plt.show()
sns.barplot(data= mc, x='label',y = 'sumamnt_ma_rech30')
plt.title('Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)')
plt.show()

# %% [markdown]
# - Total amount of recharge in main account over last 30 days is comparitively less  for defaulters account
# - On average, total amount of recharge for defaulters in main account is found to be 2000.
# - For non-defauterlts, this value is found to be 8000, which is projected slightly higher due to the presence of a seemingly impossible outlier.

# %%
sns.catplot(data= mc, x='label',y = 'medianamnt_ma_rech30')
plt.title('Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)')
plt.show()

# %% [markdown]
# - the trend appears the same for both

# %%
sns.catplot(data= mc, x='label',y = 'medianmarechprebal30')
plt.title('Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)')
plt.show()

# %% [markdown]
# - There exists similar pattern between the defaulter and non defaulter

# %%
sns.catplot(data= mc, x='label',y = 'cnt_loans30')
plt.title('Number of loans taken by user in last 30 days')
plt.show()

# %% [markdown]
# - The number of loans taken by defaulters is less in the last 30 days as compared to non-defaulters
# - We do see that there are applicants who previously have never taken a loan under non-defaulters

# %%
sns.barplot(data= mc, x='label',y = 'amnt_loans30')
plt.title('Total amount of loans taken by user in last 30 days')
plt.show()

# %% [markdown]
# - Total amount of loans taken by defaulters in last 30 days is less than non-defaulters

# %%
sns.barplot(data= mc, x='label',y = 'maxamnt_loans30')
plt.title('maximum amount of loan taken by the user in last 30 days')
plt.show()

# %% [markdown]
# - Not much differece can be observed between defaulter and non defaulter

# %%
sns.catplot(data= mc, x='label',y = 'cnt_loans90')
plt.title('Number of loans taken by user in last 90 days')
plt.show()

# %% [markdown]
# - Not much differece can be observed between defaulter and non defaulter for number of loans taken in last 90 days

# %%
sns.barplot(data= mc, x='label',y = 'amnt_loans90')
plt.title('Total amount of loans taken by user in last 90 days')
plt.show()

# %% [markdown]
# - Total amount of loans taken by defaulters in 90 days is far less than non-defaulters

# %%
sns.catplot(data= mc, x='label',y = 'maxamnt_loans90')
plt.title('maximum amount of loan taken by the user in last 90 days')
plt.show()

# %% [markdown]
# - In case of non-defaulters there are users who haven't previously taken any loans.

# %%
sns.catplot(data= mc, x='label',y = 'amnt_loans90')
plt.title('Total amount of loans taken by user in last 90 days')
plt.show()

# %% [markdown]
# - Total amount of loans taken by user in last 90 days by defaulters is far less than those by non-defaulters

# %%
sns.barplot(data= mc, x='label',y = 'payback30')
plt.title('Average payback time in days over last 30 days')
plt.show()

# %% [markdown]
# - Average payback time in days over last 30 days 2- 2.5 days for defauters
# - Average payback time in days over last 30 days 3 days for defauters

# %%
sns.barplot(data= mc, x='label',y = 'payback90')
plt.title('Average payback time in days over last 90 days')
plt.show()

# %% [markdown]
# - Average payback time over last 90 days for defaulters is seen to be 3 days and non defaulters it shows 4 days.

# %% [markdown]
# ## Correlation

# %%
corr = mc.corr()
corr
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003788      0.168293      0.166146
# aon                  -0.003788  1.000000      0.001101      0.000371
# daily_decr30          0.168293  0.001101      1.000000      0.977704
# daily_decr90          0.166146  0.000371      0.977704      1.000000
# rental30              0.058645 -0.000796      0.441532      0.434106
# rental90              0.076033 -0.000693      0.459200      0.471894
# last_rech_date_ma     0.003730  0.001692      0.000484      0.000905
# last_rech_amt_ma      0.131804  0.004253      0.275836      0.264130
# cnt_ma_rech30         0.237331 -0.003152      0.451383      0.426706
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000703      0.636535      0.603885
# medianamnt_ma_rech30  0.141490  0.004303      0.295355      0.282959
# medianmarechprebal30 -0.004843  0.003930     -0.001160     -0.000753
# ...

# %%
plt.figure(figsize=(20,25))
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %%
corr_matrix= mc.corr()
corr_matrix['label'].sort_values(ascending= False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168293
# daily_decr90            0.166146
# month                   0.154949
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.076033
# rental30                0.058645
# payback90               0.049183
# payback30               0.048336
# medianmarechprebal90    0.037126
# day                     0.006825
# cnt_loans90             0.004733
# last_rech_date_ma       0.003730
# fr_ma_rech30            0.001330
# maxamnt_loans30         0.000248
# aon                    -0.003788
# medianmarechprebal30   -0.004843
# ...

# %%
mc.drop('label',axis= 1).corrwith(mc.label).sort_values(ascending= False).plot(kind='bar', figsize = (20,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Handling outliers

# %%
mc['aon']= np.where(mc.aon >2086.0,mc['aon'].median(),mc['aon'])
mc['daily_decr30']= np.where(mc.daily_decr30 >18046.3205,mc['daily_decr30'].median(),mc['daily_decr30'])
mc['daily_decr90']= np.where(mc.daily_decr90 >19442.935000000027,mc['daily_decr90'].median(),mc['daily_decr90'])
mc['rental30']= np.where(mc.rental30 >7956.325000000001,mc['rental30'].median(),mc['rental30'])
mc['rental90']= np.where(mc.rental90 >10016.275000000027,mc['rental90'].median(),mc['rental90'])
mc['last_rech_date_ma']= np.where(mc.last_rech_date_ma >16,mc['last_rech_date_ma'].median(),mc['last_rech_date_ma'])
mc['last_rech_amt_ma']= np.where(mc.last_rech_amt_ma >4617.5,mc['last_rech_date_ma'].median(),mc['last_rech_date_ma'])
mc['cnt_ma_rech30']= np.where(mc.cnt_ma_rech30 >11,mc['cnt_ma_rech30'].median(),mc['cnt_ma_rech30'])
mc['fr_ma_rech30']= np.where(mc.fr_ma_rech30 >15,mc['fr_ma_rech30'].median(),mc['fr_ma_rech30'])
mc['sumamnt_ma_rech30']= np.where(mc.sumamnt_ma_rech30 >22715,mc['sumamnt_ma_rech30'].median(),mc['sumamnt_ma_rech30'])
mc['medianamnt_ma_rech30']= np.where(mc.medianamnt_ma_rech30 >3655,mc['medianamnt_ma_rech30'].median(),mc['medianamnt_ma_rech30'])
mc['medianmarechprebal30']= np.where(mc.medianmarechprebal30>180.8,mc['medianmarechprebal30'].median(),mc['medianmarechprebal30'])
mc['cnt_ma_rech90']= np.where(mc.fr_ma_rech90 >17,mc['cnt_ma_rech90'].median(),mc['cnt_ma_rech90'])
mc['fr_ma_rech90']= np.where(mc.fr_ma_rech90 >20,mc['fr_ma_rech90'].median(),mc['fr_ma_rech90'])
mc['sumamnt_ma_rech90']= np.where(mc.sumamnt_ma_rech90 >36524.5,mc['sumamnt_ma_rech90'].median(),mc['sumamnt_ma_rech90'])
mc['medianamnt_ma_rech90']= np.where(mc.medianamnt_ma_rech90 >3650.5,mc['medianamnt_ma_rech90'].median(),mc['medianamnt_ma_rech90'])
mc['cnt_loans30']= np.where(mc.cnt_loans30 >8.5,mc['cnt_loans30'].median(),mc['cnt_loans30'])
mc['amnt_loans30']= np.where(mc.amnt_loans30 >51,mc['amnt_loans30'].median(),mc['amnt_loans30'])
mc['cnt_loans90']= np.where(mc.cnt_loans90>11,mc['cnt_loans90'].median(),mc['cnt_loans90'])
mc['amnt_loans90']= np.where(mc.amnt_loans90 >66,mc['amnt_loans90'].median(),mc['amnt_loans90'])
mc['payback30']= np.where(mc.payback30 >9.375,mc['payback30'].median(),mc['payback30'])
mc['payback90']= np.where(mc.payback90 >11.25,mc['payback90'].median(),mc['payback90'])

# %%
df_new= mc.loc[(mc['maxamnt_loans30'] == 6) | (mc['maxamnt_loans30'] == 12)]

# %%
f =df_new[['aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_amt_ma','sumamnt_ma_rech30','medianamnt_ma_rech30','medianmarechprebal30','sumamnt_ma_rech90','medianamnt_ma_rech90','medianmarechprebal90','cnt_ma_rech30','fr_ma_rech30','cnt_ma_rech90','fr_ma_rech90','cnt_loans30','amnt_loans30','cnt_loans90','amnt_loans90','payback30','payback90']]

# %%
plt.figure(figsize =(35,35), facecolor='white')
plotnumber=1
for i in f.columns:
    if plotnumber <= 30:
        ax = plt.subplot(5,6,plotnumber)
        sns.boxplot(f[i])
        plt.xlabel(i,fontsize=20)
    
    plotnumber +=1
plt.show()

# %% [markdown]
# ## Handling Skewness

# %%
df_new.skew()
# Out:
# label                   -2.243103
# aon                      0.898796
# daily_decr30             1.561327
# daily_decr90             1.644851
# rental30                 1.547381
# rental90                 1.577294
# last_rech_date_ma        1.461533
# last_rech_amt_ma         1.633235
# cnt_ma_rech30            0.918278
# fr_ma_rech30             1.408679
# sumamnt_ma_rech30        1.101374
# medianamnt_ma_rech30     0.273599
# medianmarechprebal30     1.447757
# cnt_ma_rech90            3.479288
# fr_ma_rech90             1.847037
# sumamnt_ma_rech90        1.212093
# medianamnt_ma_rech90     0.340468
# medianmarechprebal90    45.772317
# cnt_loans30              1.334897
# amnt_loans30             1.286198
# maxamnt_loans30          2.238089
# cnt_loans90              1.437921
# amnt_loans90             1.402446
# maxamnt_loans90          2.216596
# payback30                1.359196
# payback90                1.323472
# month                    0.367014
# ...

# %%
df_new.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30',
#        'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
#        'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
#        'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'payback30', 'payback90', 'month',
#        'day'],
#       dtype='object')

# %%
f =['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
       'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30',
       'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
       'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
       'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
       'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'cnt_loans90',
       'amnt_loans90', 'maxamnt_loans90', 'payback30', 'payback90']

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method ='yeo-johnson')

# %%
df_new[f] = pt.fit_transform(df_new[f].values)

# %%
df_new[f].skew()
# Out:
# aon                    -0.059899
# daily_decr30           -0.150447
# daily_decr90           -0.142693
# rental30               -0.106256
# rental90               -0.110775
# last_rech_date_ma       0.003236
# last_rech_amt_ma       -0.001245
# cnt_ma_rech30          -0.037811
# fr_ma_rech30            0.112656
# sumamnt_ma_rech30      -0.495538
# medianamnt_ma_rech30   -0.781975
# medianmarechprebal30   -0.157157
# cnt_ma_rech90          -0.004934
# fr_ma_rech90            0.086110
# sumamnt_ma_rech90      -0.389440
# medianamnt_ma_rech90   -0.648791
# medianmarechprebal90    0.013333
# cnt_loans30             0.195050
# amnt_loans30            0.119293
# maxamnt_loans30         0.000000
# cnt_loans90             0.180642
# amnt_loans90            0.112530
# maxamnt_loans90         0.000000
# payback30               0.427538
# payback90               0.139723
# dtype: float64

# %% [markdown]
# ## Seperating into Feature and Label

# %%
X= df_new.drop('label',axis = 1)
y = df_new['label']

# %% [markdown]
# ## Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x= pd.DataFrame(scaler.fit_transform(X),columns = X.columns)
x.head()
# Out:
#         aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0  0.500109      0.721341      0.716532  0.316961  0.321689
# 1  0.702077      0.932249      0.921620  0.792942  0.745670
# 2  0.636463      0.616510      0.613424  0.509287  0.483592
# 3  0.478268      0.200044      0.201312  0.282454  0.271197
# 4  0.772847      0.367367      0.367826  0.543058  0.514969
#
#    last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0           0.395450          0.382049       0.377424      0.484039
# 1           0.497376          0.483278       0.227676      0.000000
# 2           0.497376          0.483278       0.227676      0.000000
# 3           0.497376          0.483278       0.000000      0.000000
# 4           0.575976          0.562140       0.798387      0.484039
#
#    sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 0           0.461837              0.595481              0.216941
# ...

# %% [markdown]
# ## Balacing dataset

# %%
##Balancing the dataset
from imblearn import over_sampling
from imblearn.over_sampling import SMOTE

x,y = SMOTE().fit_resample(x, y)

# %%
sns.countplot(y,data=df_new)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
y.value_counts()
# Out:
# 0    179269
# 1    179269
# Name: label, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
from sklearn.model_selection import cross_val_score

# %%
MaxAcc= 0
MaxRS =0
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=i)
    rf= RandomForestClassifier()
    rf.fit(x_train,y_train)
    predrf= rf.predict(x_test)
    acc = accuracy_score(y_test,predrf)
    print('accuracy',acc,'random_state',1)
    
    
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRS=i
print('Maximum accuracy',MaxAcc,'Random state',MaxRS)
# Out:
# accuracy 0.9513861772745021 random_state 1
# accuracy 0.9535895576504714 random_state 1
# accuracy 0.9525436492441569 random_state 1
# accuracy 0.9544681207117756 random_state 1
# accuracy 0.9539103028950745 random_state 1
# accuracy 0.9543844480392704 random_state 1
# accuracy 0.9526831036983321 random_state 1
# accuracy 0.9520137223182908 random_state 1
# accuracy 0.9530038489429352 random_state 1
# accuracy 0.9528086127070898 random_state 1
# accuracy 0.9533803759692084 random_state 1
# accuracy 0.9538126847771518 random_state 1
# accuracy 0.9531433033971105 random_state 1
# accuracy 0.95416132091259 random_state 1
# accuracy 0.9545239024934457 random_state 1
# accuracy 0.9532967032967034 random_state 1
# accuracy 0.952362358453729 random_state 1
# accuracy 0.9546075751659509 random_state 1
# accuracy 0.9534919395325486 random_state 1
# accuracy 0.9524320856808166 random_state 1
# accuracy 0.953422212305461 random_state 1
# accuracy 0.9523902493445641 random_state 1
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=15)

# %% [markdown]
# ## RandomForestClassification

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
predrf= rf.predict(x_test)
print('Accuracy',accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy 95.4189211803425
# [[34641  1430]
#  [ 1855 33782]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     36071
#            1       0.96      0.95      0.95     35637
#
#     accuracy                           0.95     71708
#    macro avg       0.95      0.95      0.95     71708
# weighted avg       0.95      0.95      0.95     71708

# %%
cv = cross_val_score(rf,x,y,cv=7)
    
print('Cross Validation Score: ', cv.mean())
print('Difference in cross val score', accuracy_score(y_test,predrf)- abs(cv.mean()))
print('**'*50)
# Out:
# Cross Validation Score:  0.9511126686424846
# Difference in cross val score 0.003076543160940415
# ****************************************************************************************************

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(rf,x_test,y_test)
plt.title('ROC AUC plot')
plt.show()

# %% [markdown]
# ## DecisionTreeClassifier

# %%
df = DecisionTreeClassifier()
df.fit(x_train,y_train)
preddf= df.predict(x_test)
print('Accuracy',accuracy_score(y_test,preddf)*100)
print(confusion_matrix(y_test,preddf))
print(classification_report(y_test,preddf))

print('**'*50)

cv = cross_val_score(df,x,y,cv=7)
    
print('Cross Validation Score: ', cv.mean())
print('Difference in cross val score', accuracy_score(y_test,preddf)- abs(cv.mean()))
# Out:
# Accuracy 91.30083114854688
# [[33233  2838]
#  [ 3400 32237]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91     36071
#            1       0.92      0.90      0.91     35637
#
#     accuracy                           0.91     71708
#    macro avg       0.91      0.91      0.91     71708
# weighted avg       0.91      0.91      0.91     71708
#
# ****************************************************************************************************
# Cross Validation Score:  0.9088187041812724
# Difference in cross val score 0.004189607304196374

# %% [markdown]
# ## KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn= knn.predict(x_test)
print('Accuracy',accuracy_score(y_test,predknn)*100)
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))

print('**'*50)

cv = cross_val_score(knn,x,y,cv=7)
    
print('Cross Validation Score: ', cv.mean())
print('Difference in cross val score', accuracy_score(y_test,predknn)- abs(cv.mean()))
# Out:
# Accuracy 90.29954816756847
# [[35830   241]
#  [ 6715 28922]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91     36071
#            1       0.99      0.81      0.89     35637
#
#     accuracy                           0.90     71708
#    macro avg       0.92      0.90      0.90     71708
# weighted avg       0.92      0.90      0.90     71708
#
# ****************************************************************************************************
# Cross Validation Score:  0.9041412708803646
# Difference in cross val score -0.0011457892046797813

# %% [markdown]
# ## AdaBoost

# %%
ada = AdaBoostClassifier()
ada.fit(x_train,y_train)
predada= ada.predict(x_test)
print('Accuracy',accuracy_score(y_test,predada)*100)
print(confusion_matrix(y_test,predada))
print(classification_report(y_test,predada))

print('**'*50)

cv = cross_val_score(ada,x,y,cv=7)
    
print('Cross Validation Score: ', cv.mean())
print('Difference in cross val score', accuracy_score(y_test,predada)- abs(cv.mean()))
# Out:
# Accuracy 84.93612985998773
# [[31270  4801]
#  [ 6001 29636]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     36071
#            1       0.86      0.83      0.85     35637
#
#     accuracy                           0.85     71708
#    macro avg       0.85      0.85      0.85     71708
# weighted avg       0.85      0.85      0.85     71708
#
# ****************************************************************************************************
# Cross Validation Score:  0.8446915458444482
# Difference in cross val score 0.004669752755429135

# %% [markdown]
# ## GradientBoosting

# %%
gbr = GradientBoostingClassifier()
gbr.fit(x_train,y_train)
predgbr= gbr.predict(x_test)
print('Accuracy',accuracy_score(y_test,predgbr)*100)
print(confusion_matrix(y_test,predgbr))
print(classification_report(y_test,predgbr))

print('**'*50)

cv = cross_val_score(gbr,x,y,cv=7)
    
print('Cross Validation Score: ', cv.mean())
print('Difference in cross val score', accuracy_score(y_test,predgbr)- abs(cv.mean()))
# Out:
# Accuracy 89.86723935962515
# [[32899  3172]
#  [ 4094 31543]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90     36071
#            1       0.91      0.89      0.90     35637
#
#     accuracy                           0.90     71708
#    macro avg       0.90      0.90      0.90     71708
# weighted avg       0.90      0.90      0.90     71708
#
# ****************************************************************************************************
# Cross Validation Score:  0.8952496693125097
# Difference in cross val score 0.003422724283741796

# %% [markdown]
# ## ROC CURVE

# %%
classifiers = [rf, df, knn, ada, gbr]
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, x_test, y_test, ax=ax)

# %% [markdown]
# - Among all the models RandomForestClassification, DecisionTreeClassifier and KNearestNeighbor has performed the best with accuracy score 95%, 91% and 90% respectively.
# - All the models have scores close to the accuracy score on cross validation.
# - In deciding the best model, we also have to take other metrics into consideration.
# - Thus, on comparing precision, recall and ROC- AUC curve, it was concluded that RandomForestClassifier should be selected as the best model.

# %% [markdown]
# ## Saving Model

# %%
import joblib

# %%
joblib.dump(rf, 'MicroCreditDefaulter')
# Out:
# ['MicroCreditDefaulter']
